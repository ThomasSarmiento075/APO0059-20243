# %%
import pandas as pd
pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv")
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cities = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv", usecols = ["City"])
pop = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos//Cities.csv", usecols = ["Population"])
pop.head()
#cities.tail()
# Out:
#    Population
# 0       21722
# 1        5629
# 2        5679
# 3       10085
# 4       23421

# %%
cities.head()
# Out:
#             City
# 0         Kajuru
# 1           Leon
# 2            Osh
# 3  Shumikhinskiy
# 4       Bundoran

# %%
cities.tail()
# Out:
#         City
# 596  Lobitos
# 597   Bremen
# 598   Harare
# 599    Lagos
# 600   Oshawa

# %%
pop.tail(n = 8)
# Out:
#      Population
# 593       16755
# 594       16325
# 595       16905
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000

# %%
cities.count()
# Out:
# City    601
# dtype: int64

# %%
pop.count()
# Out:
# Population    601
# dtype: int64

# %%
cities.describe()
# Out:
#                City
# count           601
# unique          578
# top     San Antonio
# freq              4

# %%
pop.describe()
# Out:
#          Population
# count    601.000000
# mean   13932.415973
# std     6765.873291
# min     2528.000000
# 25%     7801.000000
# 50%    13966.000000
# 75%    19752.000000
# max    38745.000000

# %%
#cities.sort_values()
cities.sort_values(by = ["City"], ascending = False)
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang
# ..             ...
# 467       Alcoutim
# 212       Alarobia
# 472          Aketi
# 66          Aizhai
# 581          Abuja
#
# [601 rows x 1 columns]

# %%
cities.sort_values(by = ["City"], ascending = False).head()
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang

# %%
cities = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv", usecols = ["City"])
cities
cities.sort_values(by = ["City"], ascending = False, inplace = True)
cities
# Out:
#               City
# 362           Zliv
# 538       Zhuoshui
# 427      Zhongxing
# 386  Zhongshangang
# 69   Zhongshangang
# ..             ...
# 467       Alcoutim
# 212       Alarobia
# 472          Aketi
# 66          Aizhai
# 581          Abuja
#
# [601 rows x 1 columns]

# %%
cities.sort_index()
# Out:
#               City
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# ..             ...
# 596        Lobitos
# 597         Bremen
# 598         Harare
# 599          Lagos
# 600         Oshawa
#
# [601 rows x 1 columns]

# %%
#cities
cities = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv")
cities.sort_index(ascending = True, inplace = True)
cities
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
print(cities)
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
import pandas as pd

data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv")
data
# Out:
#               City     Country  Population
# 0           Kajuru    Botswana       21722
# 1             Leon       Spain        5629
# 2              Osh  kyrgyzstan        5679
# 3    Shumikhinskiy      Russia       10085
# 4         Bundoran     Ireland       23421
# ..             ...         ...         ...
# 596        Lobitos        Peru       10024
# 597         Bremen     Germany        5768
# 598         Harare    Zimbabwe       16679
# 599          Lagos     Nigeria       24800
# 600         Oshawa      Canada       13000
#
# [601 rows x 3 columns]

# %%
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos//Cities.csv", index_col = ["City"])
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv", usecols = ["City"])
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv")
data.head()
# Out:
#             City     Country  Population
# 0         Kajuru    Botswana       21722
# 1           Leon       Spain        5629
# 2            Osh  kyrgyzstan        5679
# 3  Shumikhinskiy      Russia       10085
# 4       Bundoran     Ireland       23421

# %%
data[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-c402bf503b75> in <cell line: 1>()
# ----> 1 data[1]
#
# ...

# %%
cities = data["City"]
cities.head()
# Out:
# 0           Kajuru
# 1             Leon
# 2              Osh
# 3    Shumikhinskiy
# 4         Bundoran
# Name: City, dtype: object

# %%
cities[600]
# Out:
# 'Oshawa'

# %%
cities[10:20]
# Out:
# 10            Ise
# 11         Volovo
# 12         Caujul
# 13     Kutloanong
# 14       Kobuleti
# 15         Senlis
# 16         Wufeng
# 17         Picton
# 18    Johor Bahru
# 19     Fort Worth
# Name: City, dtype: object

# %%
cities[:15]
# Out:
# 0            Kajuru
# 1              Leon
# 2               Osh
# 3     Shumikhinskiy
# 4          Bundoran
# 5         La Paloma
# 6             Tutup
# 7           Ondores
# 8           Heredia
# 9              Gaio
# 10              Ise
# 11           Volovo
# 12           Caujul
# 13       Kutloanong
# 14         Kobuleti
# Name: City, dtype: object

# %%
cities[:26:2]
# Out:
# 0          Kajuru
# 2             Osh
# 4        Bundoran
# 6           Tutup
# 8         Heredia
# 10            Ise
# 12         Caujul
# 14       Kobuleti
# 16         Wufeng
# 18    Johor Bahru
# 20     Santa Cruz
# 22         Maubin
# 24          Itzer
# Name: City, dtype: object

# %%
cities[-10:]
# Out:
# 591    Bagumbayan
# 592      Tuanshan
# 593       Sapporo
# 594    Cocachacra
# 595        Kurjan
# 596       Lobitos
# 597        Bremen
# 598        Harare
# 599         Lagos
# 600        Oshawa
# Name: City, dtype: object

# %%
cities[[3, 5, 7]]
#cities.sort_values()
# Out:
# 3    Shumikhinskiy
# 5        La Paloma
# 7          Ondores
# Name: City, dtype: object

# %%
#Retrieving data from a series by index label:

#city = pd.read_csv("Cities.csv", usecols = ["City", "Country"])
city = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv", usecols = ["City", "Country"], index_col = "City")
city = city["Country"]
city
# Out:
# City
# Kajuru             Botswana
# Leon                  Spain
# Osh              kyrgyzstan
# Shumikhinskiy        Russia
# Bundoran            Ireland
#                     ...
# Lobitos                Peru
# Bremen              Germany
# Harare             Zimbabwe
# Lagos               Nigeria
# Oshawa               Canada
# Name: Country, Length: 601, dtype: object

# %%
city[0]
# Out:
# <ipython-input-31-8f5a1a4338dc>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city[0]
# 'Botswana'

# %%
city["Lobitos"]
# Out:
# City
# Lobitos    Peru
# Lobitos    Peru
# Name: Country, dtype: object

# %%
city["Kajuru"]
# Out:
# 'Botswana'

# %%
city.sort_index(inplace = True, ascending = True)
city
# Out:
# City
# Abuja                                     Nigeria
# Aizhai                                      China
# Aketi            Democratic Republic of the Congo
# Alarobia                               Madagascar
# Alcoutim                                 Portugal
#                                ...
# Zhongshangang                               China
# Zhongshangang                               China
# Zhongxing                                   China
# Zhuoshui                                    China
# Zliv                               Czech Republic
# Name: Country, Length: 601, dtype: object

# %%
city["Abuja":"Bremen"]
# Out:
# City
# Abuja                                 Nigeria
# Aizhai                                  China
# Aketi        Democratic Republic of the Congo
# Alarobia                           Madagascar
# Alcoutim                             Portugal
#                            ...
# Bolgar                                 Russia
# Bomomani                            Indonesia
# Bonavista                              Canada
# Bradag                              Indonesia
# Bremen                                Germany
# Name: Country, Length: 84, dtype: object

# %%
city[:"Bremen"]
# Out:
# City
# Abuja                                 Nigeria
# Aizhai                                  China
# Aketi        Democratic Republic of the Congo
# Alarobia                           Madagascar
# Alcoutim                             Portugal
#                            ...
# Bolgar                                 Russia
# Bomomani                            Indonesia
# Bonavista                              Canada
# Bradag                              Indonesia
# Bremen                                Germany
# Name: Country, Length: 84, dtype: object

# %%
city[["Bolgar", "Abuja", "Osh"]]
# Out:
# City
# Bolgar        Russia
# Abuja        Nigeria
# Osh       kyrgyzstan
# Name: Country, dtype: object

# %%
city.head(10)
# Out:
# City
# Abuja                                      Nigeria
# Aizhai                                       China
# Aketi             Democratic Republic of the Congo
# Alarobia                                Madagascar
# Alcoutim                                  Portugal
# Alis                                          Peru
# Alvaro Obregon                              Mexico
# Amargosa                                    Brazil
# Amuru                                       Uganda
# Anan                                         Japan
# Name: Country, dtype: object

# %%
city["Abuja": "Anan": 2]
# Out:
# City
# Abuja                                      Nigeria
# Aketi             Democratic Republic of the Congo
# Alcoutim                                  Portugal
# Alvaro Obregon                              Mexico
# Amuru                                       Uganda
# Name: Country, dtype: object

# %%
data = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Archivos/Cities.csv", usecols = ["City", "Country"], index_col = "City")
data.sort_index(inplace = True)
data
# Out:
#                                         Country
# City
# Abuja                                   Nigeria
# Aizhai                                    China
# Aketi          Democratic Republic of the Congo
# Alarobia                             Madagascar
# Alcoutim                               Portugal
# ...                                         ...
# Zhongshangang                             China
# Zhongshangang                             China
# Zhongxing                                 China
# Zhuoshui                                  China
# Zliv                             Czech Republic
#
# [601 rows x 1 columns]

# %%
city = data["Country"]
city
# Out:
# City
# Abuja                                     Nigeria
# Aizhai                                      China
# Aketi            Democratic Republic of the Congo
# Alarobia                               Madagascar
# Alcoutim                                 Portugal
#                                ...
# Zhongshangang                               China
# Zhongshangang                               China
# Zhongxing                                   China
# Zhuoshui                                    China
# Zliv                               Czech Republic
# Name: Country, Length: 601, dtype: object

# %%
city.get(0)
# Out:
# <ipython-input-42-3b8953b357aa>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city.get(0)
# 'Nigeria'

# %%
city.get([1, 5])
# Out:
# <ipython-input-43-4615aa7bec12>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   city.get([1, 5])
# City
# Aizhai    China
# Alis       Peru
# Name: Country, dtype: object

# %%
#city.get(["Aizahai", "Alis"])
print(city.get(["Aizahai", "Alis"]))
# Out:
# None

# %%
print(city.get(780))
# Out:
# None
# <ipython-input-45-bc7c82276ab4>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(city.get(780))

# %%
city.dtype      #To veriry that cuty is an object 'o'
# Out:
# dtype('O')

# %%
city.values
# Out:
# array(['Nigeria', 'China', 'Democratic Republic of the Congo',
#        'Madagascar', 'Portugal', 'Peru', 'Mexico', 'Brazil', 'Uganda',
#        'Japan', 'Peru', 'China', 'Ukraine', 'Chile', 'China', 'Canada',
#        'Peru', 'United Arab Emirates', 'Argentina', 'Colombia',
#        'Portugal', 'Portugal', 'Netherlands', 'France', 'Brazil',
#        'Brazil', 'Armenia', 'Armenia', 'France', 'France', 'Paraguay',
#        'Philippines', 'Ireland', 'Philippines', 'China', 'China', 'China',
#        'Portugal', 'Dominican Republic', 'Philippines',
#        'Bosnia and Herzegovina', 'Portugal', 'Thailand', 'Thailand',
#        'Thailand', 'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia',
#        'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia', 'Eritrea',
#        'Philippines', 'Oman', 'France', 'China', 'China', 'Brazil',
#        'Peru', 'Indonesia', 'Mexico', 'Ukraine', 'Lebanon', 'Philippines',
#        'Philippines', 'China', 'Nepal', 'Indonesia', 'Chad', 'Indonesia',
# ...

# %%
population = pop
population
# Out:
#      Population
# 0         21722
# 1          5629
# 2          5679
# 3         10085
# 4         23421
# ..          ...
# 596       10024
# 597        5768
# 598       16679
# 599       24800
# 600       13000
#
# [601 rows x 1 columns]

# %%
population = pop["Population"]
population
# Out:
# 0      21722
# 1       5629
# 2       5679
# 3      10085
# 4      23421
#        ...
# 596    10024
# 597     5768
# 598    16679
# 599    24800
# 600    13000
# Name: Population, Length: 601, dtype: int64

# %%
population.dtype
# Out:
# dtype('int64')

# %%
#pop.values
population.values
# Out:
# array([21722,  5629,  5679, 10085, 23421, 22154, 11558, 13288,  5835,
#         9942, 18354,  8184,  4672, 10733, 16577, 13265, 38745, 10120,
#        16567, 24397, 15170,  5589, 17693,  2545, 21997, 11174, 21758,
#         5860, 13204, 24943,  7476, 18560, 16422, 20559,  8519, 24805,
#        20119,  5283, 19947, 16254,  9746,  4187,  3515, 22829,  4431,
#        11071,  5972, 23638,  5217, 19156, 24196,  3106,  5428, 20167,
#        15519, 24424, 20539, 13138, 11393, 22345, 19021, 22267, 23801,
#        19485,  2653,  8634, 10173,  2528,  7332, 18425, 16527,  3103,
#        22667,  6901,  5532, 24272, 20178, 14050, 22908, 22016, 10667,
#        12517, 21987,  3900, 16041,  3507,  4002, 13997, 21675, 13299,
#        11913, 24383, 14784, 14841,  2863, 16916, 13234,  5349, 22436,
#        12620, 10021, 20120, 20168, 21621,  3695, 24722, 18096, 15913,
#        19734, 17535, 13034,  4291, 18899, 21153, 12967, 17231, 23458,
# ...

# %%
city.index
# Out:
# Index(['Abuja', 'Aizhai', 'Aketi', 'Alarobia', 'Alcoutim', 'Alis',
#        'Alvaro Obregon', 'Amargosa', 'Amuru', 'Anan',
#        ...
#        'Zhangcun', 'Zhangzhu', 'Zhatay', 'Zhentou', 'Zhiletovo',
#        'Zhongshangang', 'Zhongshangang', 'Zhongxing', 'Zhuoshui', 'Zliv'],
#       dtype='object', name='City', length=601)

# %%
population.index
# Out:
# RangeIndex(start=0, stop=601, step=1)

# %%
city.is_unique
# Out:
# False

# %%
population.is_unique
# Out:
# False

# %%
city.ndim
# Out:
# 1

# %%
#pop.ndim
population.ndim
# Out:
# 1
